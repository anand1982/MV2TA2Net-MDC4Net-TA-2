# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.preprocessing import image
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import label_binarize
from itertools import cycle
import seaborn as sns

# ==============================================================
# Configuration
# ==============================================================
data_dir = "/kaggle/input/ccmt-2008-mnit/New folder"
img_size = (224, 224)
batch_size = 32
seed = 42
num_epochs = 50
learning_rate = 1e-4
model_save_path = "resnet50_transformer_no_dropout_no_earlystop.h5"

# ==============================================================
# Dataset Loading (20% Train, 80% Test)
# ==============================================================
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    labels="inferred",
    label_mode="categorical",
    validation_split=0.2,
    subset="training",
    seed=seed,
    image_size=img_size,
    batch_size=batch_size
)

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    labels="inferred",
    label_mode="categorical",
    validation_split=0.2,
    subset="validation",
    seed=seed,
    image_size=img_size,
    batch_size=batch_size
)

class_names = train_ds.class_names
num_classes = len(class_names)
print("Detected Classes:", class_names)

AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().prefetch(AUTOTUNE)
test_ds = test_ds.cache().prefetch(AUTOTUNE)

# ==============================================================
# Transformer Encoder (NO DROPOUT)
# ==============================================================
def transformer_encoder(inputs, head_size, num_heads, ff_dim):
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    x = layers.MultiHeadAttention(
        num_heads=num_heads,
        key_dim=head_size
    )(x, x)
    x = layers.Add()([x, inputs])

    y = layers.LayerNormalization(epsilon=1e-6)(x)
    y = layers.Dense(ff_dim, activation="relu")(y)
    y = layers.Dense(x.shape[-1])(y)

    return layers.Add()([x, y])

# ==============================================================
# Model Architecture (NO DROPOUT)
# ==============================================================
def build_model(input_shape=(224,224,3),
                transformer_depth=2,
                head_dim=64,
                num_heads=4,
                ff_dim=128):

    inputs = layers.Input(shape=input_shape)

    # Normalize to [-1, 1]
    x = layers.Rescaling(1./127.5)(inputs)
    x = layers.Rescaling(1., offset=-1.0)(x)

    # ResNet50 Backbone
    backbone = MobileNetV2(
        include_top=False,
        weights="imagenet",
        input_shape=input_shape
    )
    backbone.trainable = True
    x = backbone(x)

    # Projection
    x = layers.Conv2D(head_dim, kernel_size=1, activation="relu")(x)

    # Feature map → sequence
    h, w, c = x.shape[1], x.shape[2], x.shape[3]
    seq_len = h * w
    x = layers.Reshape((seq_len, c))(x)

    # Positional Embedding
    positions = tf.range(start=0, limit=seq_len, delta=1)
    pos_embed = layers.Embedding(input_dim=seq_len, output_dim=c)(positions)
    x = x + pos_embed

    # Transformer Blocks
    for _ in range(transformer_depth):
        x = transformer_encoder(
            x,
            head_size=head_dim,
            num_heads=num_heads,
            ff_dim=ff_dim
        )

    # Classifier
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(256, activation="relu")(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    return models.Model(inputs, outputs, name="ResNet50_Transformer_NoES")

# ==============================================================
# Build & Compile
# ==============================================================
model = build_model(input_shape=img_size + (3,))
model.summary()

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# ==============================================================
# Train Model (NO EARLY STOP)
# ==============================================================
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        model_save_path,
        monitor="val_accuracy",
        save_best_only=True,
        mode="max",
        verbose=1
    )
]

history = model.fit(
    train_ds,
    epochs=num_epochs,
    validation_data=test_ds,
    callbacks=callbacks
)

# ==============================================================
# Plot Accuracy & Loss
# ==============================================================
plt.figure(figsize=(14,5))

plt.subplot(1,2,1)
plt.plot(history.history["accuracy"], label="Train")
plt.plot(history.history["val_accuracy"], label="Test")
plt.title("Accuracy")
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history["loss"], label="Train")
plt.plot(history.history["val_loss"], label="Test")
plt.title("Loss")
plt.legend()

plt.show()

# ==============================================================
# Evaluation
# ==============================================================
y_true, y_pred = [], []

for images, labels in test_ds:
    preds = model.predict(images, verbose=0)
    y_true.extend(np.argmax(labels.numpy(), axis=1))
    y_pred.extend(np.argmax(preds, axis=1))

y_true = np.array(y_true)
y_pred = np.array(y_pred)

print("\nClassification Report:\n")
print(classification_report(y_true, y_pred, target_names=class_names, digits=4))

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10,8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Greens",
            xticklabels=class_names,
            yticklabels=class_names)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()

# ==============================================================
# ROC Curve (Micro & Macro)
# ==============================================================
y_true_bin = label_binarize(y_true, classes=range(num_classes))

y_score = []
for images, _ in test_ds:
    y_score.extend(model.predict(images, verbose=0))
y_score = np.array(y_score)

fpr, tpr, roc_auc = {}, {}, {}

for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

fpr["micro"], tpr["micro"], _ = roc_curve(
    y_true_bin.ravel(),
    y_score.ravel()
)
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

all_fpr = np.unique(np.concatenate([fpr[i] for i in range(num_classes)]))
mean_tpr = np.zeros_like(all_fpr)

for i in range(num_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

mean_tpr /= num_classes
fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

plt.figure(figsize=(10,8))
colors = cycle(plt.cm.tab10.colors)

for i, color in zip(range(num_classes), colors):
    plt.plot(fpr[i], tpr[i], lw=2, color=color,
             label=f"{class_names[i]} (AUC={roc_auc[i]:.2f})")

plt.plot(fpr["micro"], tpr["micro"], linestyle=":", linewidth=3,
         label=f"Micro-average (AUC={roc_auc['micro']:.2f})")

plt.plot(fpr["macro"], tpr["macro"], linestyle=":", linewidth=3,
         label=f"Macro-average (AUC={roc_auc['macro']:.2f})")

plt.plot([0,1], [0,1], "k--", lw=1)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend(loc="lower right")
plt.show()

# ==============================================================
# Save Final Model
# ==============================================================
model.save("final_" + model_save_path)
print("Model saved successfully.")
# Out:
# Found 24981 files belonging to 22 classes.
# Using 19985 files for training.
# Found 24981 files belonging to 22 classes.
# Using 4996 files for validation.
# Detected Classes: ['anthracnose', 'bacterial blight', 'brown spot', 'fall armyworm', 'grasshoper', 'green mite', 'gumosis', 'healthy_cashew', 'healthy_cassava', 'healthy_maize', 'healthy_tomato', 'leaf beetle', 'leaf blight', 'leaf blight_tomato', 'leaf curl_tomato', 'leaf miner', 'leaf spot', 'mosaic', 'red rust', 'septoria leaf spot_tomato', 'streak virus', 'verticulium wilt_tomato']
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model: "ResNet50_Transformer_NoES"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_2         │ (None, 224, 224,  │          0 │ input_layer_2[0]… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_3         │ (None, 224, 224,  │          0 │ rescaling_2[0][0] │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mobilenetv2_1.00_2… │ (None, 7, 7,      │  2,257,984 │ rescaling_3[0][0] │
# │ (Functional)        │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 7, 7, 64)  │     81,984 │ mobilenetv2_1.00… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 49, 64)    │          0 │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 49, 64)    │          0 │ reshape_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 49, 64)    │        128 │ add_5[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 49, 64)    │     66,368 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 49, 64)    │          0 │ multi_head_atten… │
# │                     │                   │            │ add_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 49, 64)    │        128 │ add_6[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 49, 128)   │      8,320 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 49, 64)    │      8,256 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 49, 64)    │          0 │ add_6[0][0],      │
# │                     │                   │            │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 49, 64)    │        128 │ add_7[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 49, 64)    │     66,368 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 49, 64)    │          0 │ multi_head_atten… │
# │                     │                   │            │ add_7[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 49, 64)    │        128 │ add_8[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 49, 128)   │      8,320 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 49, 64)    │      8,256 │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 49, 64)    │          0 │ add_8[0][0],      │
# │                     │                   │            │ dense_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ add_9[0][0]       │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 256)       │     16,640 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 22)        │      5,654 │ dense_10[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,528,662 (9.65 MB)
#  Trainable params: 2,494,550 (9.52 MB)
#  Non-trainable params: 34,112 (133.25 KB)
# Epoch 1/50
# 2025-12-22 01:27:20.226320: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-22 01:27:20.423377: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.5317 - loss: 1.5468
# 2025-12-22 01:28:34.378174: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-22 01:28:34.576563: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.5320 - loss: 1.5459
# Epoch 1: val_accuracy improved from -inf to 0.69075, saving model to resnet50_transformer_no_dropout_no_earlystop.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 143s 144ms/step - accuracy: 0.5322 - loss: 1.5451 - val_accuracy: 0.6908 - val_loss: 0.9162
# Epoch 2/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8419 - loss: 0.4478
# Epoch 2: val_accuracy improved from 0.69075 to 0.76181, saving model to resnet50_transformer_no_dropout_no_earlystop.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 79ms/step - accuracy: 0.8419 - loss: 0.4477 - val_accuracy: 0.7618 - val_loss: 0.7223
# Epoch 3/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9405 - loss: 0.1866
# Epoch 3: val_accuracy improved from 0.76181 to 0.79143, saving model to resnet50_transformer_no_dropout_no_earlystop.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 50s 79ms/step - accuracy: 0.9406 - loss: 0.1865 - val_accuracy: 0.7914 - val_loss: 0.7714
# Epoch 4/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9851 - loss: 0.0590
# Epoch 4: val_accuracy did not improve from 0.79143
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9851 - loss: 0.0589 - val_accuracy: 0.7728 - val_loss: 0.9907
# Epoch 5/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9703 - loss: 0.0820
# Epoch 5: val_accuracy improved from 0.79143 to 0.79203, saving model to resnet50_transformer_no_dropout_no_earlystop.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 79ms/step - accuracy: 0.9703 - loss: 0.0820 - val_accuracy: 0.7920 - val_loss: 0.8770
# Epoch 6/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9723 - loss: 0.0809
# Epoch 6: val_accuracy improved from 0.79203 to 0.83727, saving model to resnet50_transformer_no_dropout_no_earlystop.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 79ms/step - accuracy: 0.9723 - loss: 0.0808 - val_accuracy: 0.8373 - val_loss: 0.7061
# Epoch 7/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9841 - loss: 0.0460
# Epoch 7: val_accuracy did not improve from 0.83727
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 79ms/step - accuracy: 0.9841 - loss: 0.0460 - val_accuracy: 0.8269 - val_loss: 0.7979
# Epoch 8/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9875 - loss: 0.0389
# Epoch 8: val_accuracy did not improve from 0.83727
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9875 - loss: 0.0389 - val_accuracy: 0.7960 - val_loss: 1.0218
# Epoch 9/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9851 - loss: 0.0434
# Epoch 9: val_accuracy did not improve from 0.83727
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9851 - loss: 0.0434 - val_accuracy: 0.8074 - val_loss: 0.9448
# Epoch 10/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9816 - loss: 0.0557
# Epoch 10: val_accuracy did not improve from 0.83727
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9816 - loss: 0.0557 - val_accuracy: 0.8237 - val_loss: 0.9011
# Epoch 11/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9930 - loss: 0.0227
# Epoch 11: val_accuracy did not improve from 0.83727
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 79ms/step - accuracy: 0.9930 - loss: 0.0227 - val_accuracy: 0.8295 - val_loss: 0.9230
# Epoch 12/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9870 - loss: 0.0375
# Epoch 12: val_accuracy did not improve from 0.83727
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9870 - loss: 0.0375 - val_accuracy: 0.8325 - val_loss: 0.8999
# Epoch 13/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9872 - loss: 0.0379
# Epoch 13: val_accuracy did not improve from 0.83727
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9872 - loss: 0.0379 - val_accuracy: 0.8149 - val_loss: 1.0514
# Epoch 14/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9873 - loss: 0.0411
# Epoch 14: val_accuracy did not improve from 0.83727
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9873 - loss: 0.0411 - val_accuracy: 0.8161 - val_loss: 1.1819
# Epoch 15/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9883 - loss: 0.0346
# Epoch 15: val_accuracy improved from 0.83727 to 0.83907, saving model to resnet50_transformer_no_dropout_no_earlystop.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 79ms/step - accuracy: 0.9883 - loss: 0.0346 - val_accuracy: 0.8391 - val_loss: 0.9668
# Epoch 16/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9906 - loss: 0.0299
# Epoch 16: val_accuracy did not improve from 0.83907
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9906 - loss: 0.0299 - val_accuracy: 0.7986 - val_loss: 1.0882
# Epoch 17/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9924 - loss: 0.0239
# Epoch 17: val_accuracy did not improve from 0.83907
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9924 - loss: 0.0239 - val_accuracy: 0.8187 - val_loss: 1.0485
# Epoch 18/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9932 - loss: 0.0227
# Epoch 18: val_accuracy did not improve from 0.83907
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9932 - loss: 0.0227 - val_accuracy: 0.8277 - val_loss: 0.9405
# Epoch 19/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9882 - loss: 0.0362
# Epoch 19: val_accuracy did not improve from 0.83907
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9882 - loss: 0.0362 - val_accuracy: 0.8185 - val_loss: 1.0351
# Epoch 20/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9884 - loss: 0.0320
# Epoch 20: val_accuracy did not improve from 0.83907
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9884 - loss: 0.0320 - val_accuracy: 0.8365 - val_loss: 0.9372
# Epoch 21/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9940 - loss: 0.0200
# Epoch 21: val_accuracy did not improve from 0.83907
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9940 - loss: 0.0200 - val_accuracy: 0.8333 - val_loss: 0.9874
# Epoch 22/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9891 - loss: 0.0318
# Epoch 22: val_accuracy did not improve from 0.83907
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9891 - loss: 0.0318 - val_accuracy: 0.8265 - val_loss: 1.0208
# Epoch 23/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9877 - loss: 0.0321
# Epoch 23: val_accuracy did not improve from 0.83907
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9877 - loss: 0.0321 - val_accuracy: 0.8339 - val_loss: 1.0054
# Epoch 24/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9922 - loss: 0.0258
# Epoch 24: val_accuracy improved from 0.83907 to 0.84848, saving model to resnet50_transformer_no_dropout_no_earlystop.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 79ms/step - accuracy: 0.9922 - loss: 0.0258 - val_accuracy: 0.8485 - val_loss: 0.9282
# Epoch 25/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9967 - loss: 0.0104
# Epoch 25: val_accuracy did not improve from 0.84848
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9967 - loss: 0.0104 - val_accuracy: 0.8273 - val_loss: 0.9821
# Epoch 26/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9904 - loss: 0.0287
# Epoch 26: val_accuracy did not improve from 0.84848
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9904 - loss: 0.0287 - val_accuracy: 0.8171 - val_loss: 0.9158
# Epoch 27/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9875 - loss: 0.0370
# Epoch 27: val_accuracy did not improve from 0.84848
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9876 - loss: 0.0370 - val_accuracy: 0.8335 - val_loss: 0.9026
# Epoch 28/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9951 - loss: 0.0172
# Epoch 28: val_accuracy improved from 0.84848 to 0.85448, saving model to resnet50_transformer_no_dropout_no_earlystop.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 79ms/step - accuracy: 0.9951 - loss: 0.0172 - val_accuracy: 0.8545 - val_loss: 0.8053
# Epoch 29/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9986 - loss: 0.0055
# Epoch 29: val_accuracy improved from 0.85448 to 0.85889, saving model to resnet50_transformer_no_dropout_no_earlystop.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 79ms/step - accuracy: 0.9986 - loss: 0.0055 - val_accuracy: 0.8589 - val_loss: 0.7906
# Epoch 30/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9968 - loss: 0.0105
# Epoch 30: val_accuracy did not improve from 0.85889
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9968 - loss: 0.0105 - val_accuracy: 0.8153 - val_loss: 1.0628
# Epoch 31/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9811 - loss: 0.0598
# Epoch 31: val_accuracy did not improve from 0.85889
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9811 - loss: 0.0597 - val_accuracy: 0.8483 - val_loss: 0.9814
# Epoch 32/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9945 - loss: 0.0147
# Epoch 32: val_accuracy improved from 0.85889 to 0.86309, saving model to resnet50_transformer_no_dropout_no_earlystop.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 79ms/step - accuracy: 0.9945 - loss: 0.0147 - val_accuracy: 0.8631 - val_loss: 0.8799
# Epoch 33/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9967 - loss: 0.0120
# Epoch 33: val_accuracy did not improve from 0.86309
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9967 - loss: 0.0120 - val_accuracy: 0.8537 - val_loss: 0.9705
# Epoch 34/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9933 - loss: 0.0249
# Epoch 34: val_accuracy did not improve from 0.86309
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9933 - loss: 0.0249 - val_accuracy: 0.8189 - val_loss: 1.1795
# Epoch 35/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9876 - loss: 0.0447
# Epoch 35: val_accuracy did not improve from 0.86309
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9876 - loss: 0.0447 - val_accuracy: 0.8403 - val_loss: 0.8785
# Epoch 36/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9955 - loss: 0.0174
# Epoch 36: val_accuracy did not improve from 0.86309
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9955 - loss: 0.0174 - val_accuracy: 0.8531 - val_loss: 0.8711
# Epoch 37/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9946 - loss: 0.0158
# Epoch 37: val_accuracy did not improve from 0.86309
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9946 - loss: 0.0158 - val_accuracy: 0.8443 - val_loss: 0.8522
# Epoch 38/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9925 - loss: 0.0219
# Epoch 38: val_accuracy did not improve from 0.86309
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9925 - loss: 0.0219 - val_accuracy: 0.8499 - val_loss: 0.7977
# Epoch 39/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9940 - loss: 0.0171
# Epoch 39: val_accuracy did not improve from 0.86309
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9940 - loss: 0.0171 - val_accuracy: 0.8425 - val_loss: 0.8987
# Epoch 40/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9965 - loss: 0.0132
# Epoch 40: val_accuracy did not improve from 0.86309
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9965 - loss: 0.0132 - val_accuracy: 0.8567 - val_loss: 0.8790
# Epoch 41/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9948 - loss: 0.0158
# Epoch 41: val_accuracy did not improve from 0.86309
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9948 - loss: 0.0158 - val_accuracy: 0.8439 - val_loss: 0.8807
# Epoch 42/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9929 - loss: 0.0219
# Epoch 42: val_accuracy did not improve from 0.86309
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9929 - loss: 0.0219 - val_accuracy: 0.8445 - val_loss: 0.9183
# Epoch 43/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9950 - loss: 0.0150
# Epoch 43: val_accuracy did not improve from 0.86309
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9950 - loss: 0.0150 - val_accuracy: 0.8501 - val_loss: 0.9329
# Epoch 44/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9932 - loss: 0.0220
# Epoch 44: val_accuracy did not improve from 0.86309
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9932 - loss: 0.0220 - val_accuracy: 0.8463 - val_loss: 0.9070
# Epoch 45/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9949 - loss: 0.0174
# Epoch 45: val_accuracy did not improve from 0.86309
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 50s 79ms/step - accuracy: 0.9949 - loss: 0.0174 - val_accuracy: 0.8507 - val_loss: 0.8737
# Epoch 46/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9942 - loss: 0.0175
# Epoch 46: val_accuracy did not improve from 0.86309
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9942 - loss: 0.0175 - val_accuracy: 0.8421 - val_loss: 0.8834
# Epoch 47/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9962 - loss: 0.0129
# Epoch 47: val_accuracy improved from 0.86309 to 0.86549, saving model to resnet50_transformer_no_dropout_no_earlystop.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 79ms/step - accuracy: 0.9962 - loss: 0.0129 - val_accuracy: 0.8655 - val_loss: 0.8695
# Epoch 48/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9944 - loss: 0.0182
# Epoch 48: val_accuracy did not improve from 0.86549
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9944 - loss: 0.0183 - val_accuracy: 0.8425 - val_loss: 0.9800
# Epoch 49/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9907 - loss: 0.0266
# Epoch 49: val_accuracy did not improve from 0.86549
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9907 - loss: 0.0266 - val_accuracy: 0.8575 - val_loss: 0.8888
# Epoch 50/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9970 - loss: 0.0094
# Epoch 50: val_accuracy did not improve from 0.86549
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9970 - loss: 0.0094 - val_accuracy: 0.8595 - val_loss: 0.8941
# Classification Report:
#
#                            precision    recall  f1-score   support
#
#               anthracnose     0.9716    0.8485    0.9059       363
#          bacterial blight     0.9070    0.8512    0.8782       504
#                brown spot     0.8635    0.9238    0.8926       315
#             fall armyworm     0.8857    0.6739    0.7654        46
#                grasshoper     0.8916    0.8315    0.8605        89
#                green mite     0.8153    0.9141    0.8619       198
#                   gumosis     0.9873    1.0000    0.9936        78
#            healthy_cashew     0.9697    0.9614    0.9655       233
#           healthy_cassava     0.9814    0.9420    0.9613       224
#             healthy_maize     0.8511    0.7273    0.7843        55
#            healthy_tomato     0.9167    0.9706    0.9429       102
#               leaf beetle     0.9752    0.9381    0.9563       210
#               leaf blight     0.7263    0.7263    0.7263       190
#        leaf blight_tomato     0.7138    0.7823    0.7465       271
#          leaf curl_tomato     0.5769    0.5625    0.5696        80
#                leaf miner     0.9094    0.9656    0.9367       291
#                 leaf spot     0.6325    0.7925    0.7035       241
#                    mosaic     0.8246    0.9485    0.8822       233
#                  red rust     0.9752    0.9825    0.9788       400
# septoria leaf spot_tomato     0.7974    0.7757    0.7864       477
#              streak virus     0.9000    0.7435    0.8143       230
#   verticulium wilt_tomato     0.7466    0.6566    0.6987       166
#
#                  accuracy                         0.8595      4996
#                 macro avg     0.8554    0.8417    0.8460      4996
#              weighted avg     0.8646    0.8595    0.8600      4996
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully.
